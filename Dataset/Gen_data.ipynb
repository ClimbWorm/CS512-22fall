# %%
from pandas import HDFStore 
from pandas import (
    DataFrame, HDFStore
)
import pandas as pd
import numpy as np
import h5py
import glob
import os
import codecs

# %%
h5new = HDFStore('pems_all_2022.h5')
df_new = h5new['speed']
#df
h5all.close()
h5all = HDFStore('pems-bay.h5')
df = h5all['speed']
df
# Out:
# sensor_id            400001  400017  400030  400040  400045  400052  400057  \
# 2017-01-01 00:00:00    71.4    67.8    70.5    67.4    68.8    66.6    66.8
# 2017-01-01 00:05:00    71.6    67.5    70.6    67.5    68.7    66.6    66.8
# 2017-01-01 00:10:00    71.6    67.6    70.2    67.4    68.7    66.1    66.8
# 2017-01-01 00:15:00    71.1    67.5    70.3    68.0    68.5    66.7    66.6
# 2017-01-01 00:20:00    71.7    67.8    70.2    68.1    68.4    66.9    66.1
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2017-06-30 23:35:00    70.9    66.3    68.4    61.0    61.8    66.9    66.0
# 2017-06-30 23:40:00    71.3    66.6    68.7    60.9    62.0    66.2    66.5
# 2017-06-30 23:45:00    71.4    66.9    68.1    61.1    62.0    66.7    65.8
# 2017-06-30 23:50:00    72.2    66.5    68.0    61.1    62.5    65.8    67.1
# 2017-06-30 23:55:00    71.5    66.2    68.4    61.5    62.8    66.1    67.7
#
# sensor_id            400059  400065  400069  ...  409525  409526  409528  \
# 2017-01-01 00:00:00    68.0    66.8    69.0  ...    68.8    67.9    68.8
# 2017-01-01 00:05:00    67.8    66.5    68.2  ...    68.4    67.3    68.4
# 2017-01-01 00:10:00    67.8    66.2    67.8  ...    68.4    67.4    68.4
# 2017-01-01 00:15:00    67.7    65.9    67.8  ...    68.5    67.5    68.5
# 2017-01-01 00:20:00    67.7    66.1    67.8  ...    68.5    67.7    68.5
# ...                     ...     ...     ...  ...     ...     ...     ...
# 2017-06-30 23:35:00    67.4    65.4    69.3  ...    64.6    66.8    64.7
# 2017-06-30 23:40:00    68.2    64.9    69.1  ...    65.1    67.3    64.8
# 2017-06-30 23:45:00    68.2    64.2    69.1  ...    64.9    66.5    64.6
# 2017-06-30 23:50:00    68.3    64.0    67.3  ...    64.1    65.9    64.8
# 2017-06-30 23:55:00    68.4    64.9    68.0  ...    64.3    66.5    64.8
#
# sensor_id            409529  413026  413845  413877  413878  414284  414694
# 2017-01-01 00:00:00    68.0    69.2    68.9    70.4    68.8    71.1    68.0
# 2017-01-01 00:05:00    67.6    70.4    68.8    70.1    68.4    70.8    67.4
# 2017-01-01 00:10:00    67.5    70.2    68.3    69.8    68.4    70.5    67.9
# 2017-01-01 00:15:00    67.5    70.4    68.7    70.2    68.4    70.8    67.6
# 2017-01-01 00:20:00    67.4    69.6    69.1    70.0    68.4    71.0    67.9
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2017-06-30 23:35:00    61.1    68.4    61.4    70.5    68.2    71.6    66.2
# 2017-06-30 23:40:00    60.8    69.8    62.2    69.4    68.6    71.6    68.4
# 2017-06-30 23:45:00    61.3    69.5    63.8    70.6    68.4    71.6    66.6
# 2017-06-30 23:50:00    61.3    69.6    64.2    70.2    68.7    71.6    68.4
# 2017-06-30 23:55:00    60.9    70.9    63.4    70.3    68.7    71.6    68.0
#
# [52116 rows x 325 columns]

# %%
#time_ind, time_in_day.shape
from dateutil.parser import parse
from datetime import datetime
date = df_new.index.values[0]
# date

date_time_str = '01/13/2022 00:00:00'

def parse_time(date):
    date_time_obj = datetime.strptime(date, '%m/%d/%Y %H:%M:%S').strftime('%Y-%m-%d %H:%M:%S')
    return date_time_obj

# %%
date_array = df_new.index.values
date2 = '01/13/2022 00:00:00'
date_array_new = np.array(list(map(parse_time, date_array)))
#date_array_new = parse_time(date2)
regulared_index_value = date_array_new.astype("datetime64[ns]")

# %%
date = df.index.values
date
# Out:
# array(['2017-01-01T00:00:00.000000000', '2017-01-01T00:05:00.000000000',
#        '2017-01-01T00:10:00.000000000', ...,
#        '2017-06-30T23:45:00.000000000', '2017-06-30T23:50:00.000000000',
#        '2017-06-30T23:55:00.000000000'], dtype='datetime64[ns]')

# %%
df_new_regular = df_new
df_new_regular = df_new_regular.set_axis(regulared_index_value)
df_new_regular
# Out:
# sensor_id            400001  400017  400030  400040  400045  400052  400057  \
# 2022-01-01 00:00:00    71.8    68.1    68.1    67.9    68.1    68.8    68.2
# 2022-01-01 00:05:00    71.1    68.0    68.1    67.4    68.0    68.7    68.0
# 2022-01-01 00:10:00    70.9    68.0    68.1    67.7    68.0    68.5    68.0
# 2022-01-01 00:15:00    71.3    67.8    68.2    67.6    67.8    69.0    67.9
# 2022-01-01 00:20:00    70.7    67.8    68.0    67.3    67.8    68.0    67.9
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2022-06-30 23:35:00    71.1    64.9    68.7    68.3    67.7    66.6    67.3
# 2022-06-30 23:40:00    71.4    64.7    67.6    67.5    67.8    66.1    67.8
# 2022-06-30 23:45:00    71.4    64.8    67.0    66.9    67.7    66.8    67.1
# 2022-06-30 23:50:00    72.5    64.4    68.3    67.7    67.8    67.1    67.7
# 2022-06-30 23:55:00    72.2    64.7    66.8    68.1    67.8    66.7    67.1
#
# sensor_id            400059  400065  400069  ...  409525  409526  409528  \
# 2022-01-01 00:00:00    68.2    66.7    69.8  ...    67.6    68.2    66.2
# 2022-01-01 00:05:00    68.2    66.4    69.1  ...    67.7    68.0    66.5
# 2022-01-01 00:10:00    67.3    66.5    69.7  ...    67.3    68.0    66.1
# 2022-01-01 00:15:00    67.7    66.1    68.4  ...    67.7    67.9    66.6
# 2022-01-01 00:20:00    67.6    66.6    66.9  ...    67.7    67.9    65.5
# ...                     ...     ...     ...  ...     ...     ...     ...
# 2022-06-30 23:35:00    59.1    67.0    48.1  ...    64.5    67.7    65.7
# 2022-06-30 23:40:00    59.3    66.5    46.8  ...    64.4    67.8    64.8
# 2022-06-30 23:45:00    59.0    66.8    49.1  ...    63.5    67.8    65.2
# 2022-06-30 23:50:00    59.4    66.8    49.2  ...    64.4    67.8    64.8
# 2022-06-30 23:55:00    61.8    66.1    48.1  ...    64.5    67.8    65.3
#
# sensor_id            409529  413026  413845  413877  413878  414284  414694
# 2022-01-01 00:00:00    68.2    72.4    68.7    69.8    68.3    71.4    67.8
# 2022-01-01 00:05:00    68.0    72.6    68.7    70.2    68.2    71.3    68.4
# 2022-01-01 00:10:00    68.0    72.1    67.9    70.1    68.0    71.0    67.5
# 2022-01-01 00:15:00    67.9    71.5    67.9    69.9    68.0    70.4    67.6
# 2022-01-01 00:20:00    67.9    70.4    68.8    70.4    67.5    70.8    68.0
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2022-06-30 23:35:00    67.7    71.9    67.7    68.2    67.6    70.9    66.4
# 2022-06-30 23:40:00    67.8    70.3    69.5    67.7    66.5    70.1    67.6
# 2022-06-30 23:45:00    67.8    70.9    69.3    67.9    66.9    70.7    66.9
# 2022-06-30 23:50:00    67.8    69.7    69.5    67.8    67.4    71.0    67.8
# 2022-06-30 23:55:00    67.8    71.6    68.4    67.6    67.2    70.8    66.6
#
# [51649 rows x 319 columns]

# %%
#df_new_index = df_new_regular.index.values
df_new_index.shape
# Out:
# (51649,)

# %%
#df = pd.read_hdf('pems_all_2022.h5', 'speed')
# 0 is the latest observed sample.
x_offsets = np.sort(
# np.concatenate(([-week_size + 1, -day_size + 1], np.arange(-11, 1, 1)))
np.concatenate((np.arange(-11, 1, 1),)))
#[-11 , -10, -9 ...0]
# Predict the next one hour
y_offsets = np.sort(np.arange(1, 13, 1))
#[1, 2, 3, 4, ...12]
# x_offsets, y_offsets

# %%
#num_samples, num_nodes = df.shape
num_samples, num_nodes = df_new_regular.shape
data = np.expand_dims(df_new_regular.values, axis=-1)# slice by rows
data_list = [data]
time_ind = (df_new_regular.index.values - df_new_regular.index.values.astype("datetime64[D]")) / np.timedelta64(1, "D")
time_in_day = np.tile(time_ind, [1, num_nodes, 1]).transpose((2, 1, 0))

# %%
data_list.append(time_in_day)
data = np.concatenate(data_list, axis=-1)

# %%
#data contains 51649 rows, [319,2] elemments, 319 sensors with [speed, time]
#data[0].shape
# Out:
# (319, 2)

# %%
# epoch_len = num_samples + min(x_offsets) - max(y_offsets)
x, y = [], []
# t is the index of the last observation.
min_t = abs(min(x_offsets))#11
max_t = abs(num_samples - abs(max(y_offsets)))  # Exclusive 51649 - 12
for t in range(min_t, max_t):#11 to 51649 - 12
    x_t = data[t + x_offsets, ...] #[0-11, ...], [1-12, ...]
    y_t = data[t + y_offsets, ...]#[11+[1,2,3,...,12], ...]
    x.append(x_t)
    y.append(y_t)
x = np.stack(x, axis=0)
y = np.stack(y, axis=0)

# %%
#min_t, max_t[0-11, ...]
data[11+x_offsets, ...]
# Out:
# array([[[7.18000000e+01, 0.00000000e+00],
#         [6.81000000e+01, 0.00000000e+00],
#         [6.81000000e+01, 0.00000000e+00],
#         ...,
#         [6.83000000e+01, 0.00000000e+00],
#         [7.14000000e+01, 0.00000000e+00],
#         [6.78000000e+01, 0.00000000e+00]],
#
#        [[7.11000000e+01, 3.47222222e-03],
#         [6.80000000e+01, 3.47222222e-03],
#         [6.81000000e+01, 3.47222222e-03],
#         ...,
#         [6.82000000e+01, 3.47222222e-03],
#         [7.13000000e+01, 3.47222222e-03],
#         [6.84000000e+01, 3.47222222e-03]],
#
#        [[7.09000000e+01, 6.94444444e-03],
#         [6.80000000e+01, 6.94444444e-03],
#         [6.81000000e+01, 6.94444444e-03],
#         ...,
#         [6.80000000e+01, 6.94444444e-03],
#         [7.10000000e+01, 6.94444444e-03],
#         [6.75000000e+01, 6.94444444e-03]],
#
#        ...,
#
#        [[7.11000000e+01, 3.12500000e-02],
#         [6.77000000e+01, 3.12500000e-02],
#         [6.73000000e+01, 3.12500000e-02],
#         ...,
#         [6.86000000e+01, 3.12500000e-02],
#         [7.13000000e+01, 3.12500000e-02],
#         [6.73000000e+01, 3.12500000e-02]],
#
#        [[7.10000000e+01, 3.47222222e-02],
#         [6.78000000e+01, 3.47222222e-02],
#         [6.71000000e+01, 3.47222222e-02],
#         ...,
#         [6.82000000e+01, 3.47222222e-02],
#         [7.11000000e+01, 3.47222222e-02],
#         [6.70000000e+01, 3.47222222e-02]],
#
#        [[7.06000000e+01, 3.81944444e-02],
#         [6.77000000e+01, 3.81944444e-02],
#         [6.74000000e+01, 3.81944444e-02],
#         ...,
#         [6.80000000e+01, 3.81944444e-02],
#         [7.12000000e+01, 3.81944444e-02],
#         [6.77000000e+01, 3.81944444e-02]]])
